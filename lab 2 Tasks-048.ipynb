# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahsan-1114/LAB-AI/blob/main/lab%202%20Tasks-048.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1
x=[]
y=[]
n1= int(input("enter the number of elements "))
for i in range (1,n1+1):
    z= int(input("enter the  elements "))
    x.append(z)
n2= int(input("enter the number of elements "))
for i in range (1,n2+1):
    w= int(input("enter the  elements "))
    y.append(w)
merge_list= x+y       
print("Merge list",merge_list)
merge_list.sort()      
print("sorted list",merge_list)

#Task 2
x=[]
y=[]
n1= int(input("enter the number of elements "))
for i in range (1,n1+1):
    z= int(input("enter the  elements "))
    x.append(z)
n2= int(input("enter the number of elements "))
for i in range (1,n2+1):
    w= int(input("enter the  elements "))
    y.append(w)
merge_list= x+y       
print("Merge list",merge_list)
merge_list.sort()      
print("sorted list",merge_list)
print("smallest number is", x[0])
print("Largest number is", y[-1])

#Tasks 3
from math import *
x=0.001
for i in range(0,360,30):
    print ("The value of sin and cos at ",i)
    y=((sin(i+x)-(sin(i)))/x)
    print("value of sin ",y)
    print("value of cos ",cos(i))

#Tasks 4
birthdayDictionary={"ali":"3/06","Ahmed":"15/07","Taha":"20/10"}
print("We knaow the birthdays of",birthdayDictionary.keys())
name=input("Who's birthday do you want to look up?")
print(name,"'s birthday is on",birthdayDictionary[name])

#Task 5
contactThings =[{"name": ["Ali"],
                 "age": ["25"],
                 "city": ["New york"],
                 "salary": [8000]}]
[{"name": ["Ali"],
                 "salary": [8000]}]

list1 = ''
list2 = ''
list3 = []
testDictionary = {}

for item in contactThings:
    list1 = item["name"]
    list2 = item["salary"]

testDictionary = {}

for w in list1:
    for l in list2:
        testDictionary["name"] = w
        testDictionary["salary"] = l
        list3.append(testDictionary)

print(list3)
# Out:
# enter the number of elements 2
# enter the  elements 22
# enter the  elements 21
# enter the number of elements 2
# enter the  elements 54
# enter the  elements 43
# Merge list [22, 21, 54, 43]
# sorted list [21, 22, 43, 54]
# enter the number of elements 2
# enter the  elements 32
# enter the  elements 23
# enter the number of elements 2
# enter the  elements 56
# enter the  elements 55
# Merge list [32, 23, 56, 55]
# sorted list [23, 32, 55, 56]
# smallest number is 32
# Largest number is 55
# The value of sin and cos at  0
# value of sin  0.9999998333333416
# value of cos  1.0
# The value of sin and cos at  30
# value of sin  0.15474543995008805
# value of cos  0.15425144988758405
# The value of sin and cos at  60
# value of sin  -0.9522604163796355
# value of cos  -0.9524129804151563
# The value of sin and cos at  90
# value of sin  -0.4485205397468661
# value of cos  -0.4480736161291701
# The value of sin and cos at  120
# value of sin  0.8138905292657261
# ...
